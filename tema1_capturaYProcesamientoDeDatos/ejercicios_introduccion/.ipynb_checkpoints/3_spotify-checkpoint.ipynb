# %% [markdown]
# # Introducción a la ciencia de datos con Python
# ###  Rafa Caballero
#
# ### API Spotify
#
# Veamos un ejemplo de uso de API "cubierta" por una librería, en este caso la librería `spotipy` para acceder a datos de Spotify. Más detalles en: https://spotipy.readthedocs.io/en/2.16.1/
#
# Primero instalamos la librería spotipy

# %%
    # !pip install spotipy

# %% [markdown]
# Necesitaremos una cuenta, aunque sea gratuita, para crear una app y obtener las credenciales

# %%
# se obtienen desde https://developer.spotify.com/dashboard/
import os
os.environ["SPOTIPY_CLIENT_ID"] = "c4dc3fba88c94833aea9541328214267"
os.environ["SPOTIPY_CLIENT_SECRET"] = "2f5091aef9f54360b8435a59b29125b8"
os.environ["SPOTIPY_REDIRECT_URI"] = "http://localhost:8080"

# %% [markdown]
# A partir de aquí se pueden realizar muchas consultas sobre artistas, sus canciones más escuchadas, etc.

# %%
import spotipy
import sys
from spotipy.oauth2 import SpotifyClientCredentials

spotify = spotipy.Spotify(auth_manager=SpotifyClientCredentials())

name = 'AC/DC'

results = spotify.search(q='artist:' + name, type='artist')
items = results['artists']['items']
if len(items) > 0:
    artist = items[0]
    print(artist['name'], artist['images'][0]['url'])
# Out:
# AC/DC https://i.scdn.co/image/ab6761610000e5ebc4c77549095c86acb4e77b37

# %% [markdown]
# Con un poquito de magía (y de nuevo la librería requests) podemos obtener la imagen directamente

# %%
from PIL import Image
import requests

im = Image.open(requests.get(artist['images'][0]['url'], stream=True).raw)
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>

# %%
    
results = spotify.artist_top_tracks("711MCceyCBcFnzjGY4Q7Un")

for track in results['tracks'][:2]:
    print('track    : ' + track['name'])
    print('audio    : ' + track['preview_url'])
    print('cover art: ' + track['album']['images'][0]['url'])
    print()
# Out:
# track    : Back In Black
# audio    : https://p.scdn.co/mp3-preview/41f8586f16bc642b45122e52041143789a8e00c0?cid=c4dc3fba88c94833aea9541328214267
# cover art: https://i.scdn.co/image/ab67616d0000b2730b51f8d91f3a21e8426361ae
#
# track    : Highway to Hell
# audio    : https://p.scdn.co/mp3-preview/3589df13595d1ab1a2667db423b76c7e1e86ed73?cid=c4dc3fba88c94833aea9541328214267
# cover art: https://i.scdn.co/image/ab67616d0000b27351c02a77d09dfcd53c8676d0

# %%
import requests
url = track['preview_url']
nombre = "./3_explicacion_BackInBlack.mp3"
r = requests.get(url, allow_redirects=True) # el fichero queda en la variable r
open(nombre, 'wb').write(r.content) # ahora lo grabamos localmente
# Out:
# 361921
