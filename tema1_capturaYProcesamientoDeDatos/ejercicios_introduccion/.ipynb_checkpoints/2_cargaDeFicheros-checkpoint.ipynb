# %% [markdown]
# # Introducción a la ciencia de datos con Python
# ###  Rafa Caballero
#
# # Caso práctico: carga de ficheros
#
#
# Puedes usar el siguiente índice para saltar a la sección adecuado
#
#
# **Índice**
#
# [Descarga de ficheros](#Descarga-de-ficheros)
#
# [APIs](#API)
#
# [Carga de ficheros CSV con Pandas](#Carga-de-ficheros-CSV-con-Pandas)
#
# [Carga de ficheros Excel con Pandas](#Carga-de-ficheros-Excel-con-Pandas)
#
# [Extracción de información de ficheros PDF](#Carga-de-ficheros-PDF)

# %% [markdown]
# <a name="Descarga-de-ficheros"></a>
# ### Descarga de ficheros
#
# Como veremos, en algunos casos las librerías correspondientes nos permitirán cargar directamente datos a partir de un enlace en internet. Sin embargo, en otras ocasiones tendremos que seguir dos pasos
#
#   1.- Descargar el fichero que queramos usando la librería `requests`
#
#   2.- Manipular el fichero, ya en local, mediante la librería adecuada
#
# Vamos a ver un ejemplo muy sencillo de descarga del último fichero con los datos de inflación.

# %%
import requests
url = "https://www.bolsamadrid.es/docs/SBolsas/InformesSB/resumen.pdf"
nombre = "2_resumenBolsa.pdf"

r = requests.get(url, allow_redirects=True) # el fichero queda en la variable r
open(nombre, 'wb').write(r.content) # ahora lo grabamos localmente
# Out:
# 56799

# %% [markdown]
# Se puede comprabar si el fichero se ha descargado bien comprobando el `r.status_code`, que será 200 si todo ha sido correcto.

# %%
print(r.status_code)

# %% [markdown]
# *   200: Todo ha ido bien
# *   301: La página redirige a otra; esto podemose evitarlo con `allow_redirects=True`
# *  400: El servidor no existe o el formato de algún parámetro es erróneo
# * 401: Error de autentificación
# * 403: No tenemos permisos para acceder al recurso
# * 404: El recurso no existe aunque el servidor sí
# * 503: El servidor existe pero no puede atender la demanda
#
# Por tanto el proceso ha tenido este aspecto:
#
# <img src="https://www.dataquest.io/wp-content/uploads/2019/09/api-request.svg"></img>
#
#
# Además, [requests](https://docs.python-requests.org/) permite pasar parámetros, autenticarse con user, password, descargar de forma "perezosa" para ficheros que no caben en memoria, etc.
#
# También puede utilizarse para descargar páginas html y examinarlas extrayendo información. Sin embargo, para esto es preferible utilizar librerías como `BeautifulSoup` o, si se tiene que interaccionar con la página, `Selenium`

# %% [markdown]
# **Ejercicio 1** Descargar el Balance de Actividad del año 2021 disponible en "https://www.bolsasymercados.es/docs/infmercado/2021/esp/IM2021.pdf". Grabar el fichero localmente con nombre "informe21.pdf"
#
# Mostrar el status de la descarga a ver si todo está bien

# %%
#import requests

url="https://www.bolsasymercados.es/docs/infmercado/2021/esp/IM2021.pdf"
nombre="2_ejercicio1_informe21.pdf"

r=requests.get(url)
open(nombre, "wb").write(r.content)
print("Status: ",r.status_code)
# Out:
# Status:  200

# %% [markdown]
# **Ejercicio 2** Probar a modificar la URL para que corresponda al ejercicio 2022:
#
# https://www.bolsasymercados.es/docs/infmercado/2021/esp/IM2022.pdf
#
# y comprobar que el status nos devuelve un error. Grabar el fichero localmente con nombre "informe22.pdf"

# %%
import requests

url="https://www.bolsasymercados.es/docs/infmercado/2021/esp/IM2022.pdf"
nombre="2_ejercicio2_informe22.pdf"

r=requests.get(url)
open(nombre, "wb").write(r.content)
print("Status: ",r.status_code)
# Out:
# Status:  404

# %% [markdown]
# <a name="API"></a>
# ### APIs
#
# La librería `requests` también es útil para descargar información que no está directamente en una página sino que se puede obtener a partir de una API (Application Program Interface), es decir un servicio que nos proporciona un sitio que contiene los datos utilizando una secuencia de datos bien definida (protocolo).
#
#
# **Ejemplo**
#
# En este ejempo accedemos a la API de la agencia nacional de meteorología.
#
# Para acceder necesitaremos una clave que podemos obtener [aquí](https://opendata.aemet.es/centrodedescargas/altaUsuario?)
#
# La API nos devuelve la información en dos pasos:
#
# 1º Una primera llamada a requests.get con la URL correspondiente al dato que queremos pedir (ver [aqui](https://opendata.aemet.es/dist/index.html?) una lista de posibilidades) y nuestra clave de API nos devolverá un link al fichero con datos y fichero con metadatos
#
# 2º Una segunda llamada a requests.get nos permitirá ya obtener los datos y los metadatos con los links devueltos por el paso 1. Además, en esta segunda operación no hace falta la clave de API.
#
# En el siguiente ejemplo vamos a acceder a los datos de las últimas 24 horas de la estación de Navacerrada (código 2462)

# %%
import json # para convertir string a JSON
import requests # para descargar ficheros
import pprint # para mostrar JSON en "bonito"

api_key = "eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJyYWZhY3JAdWNtLmVzIiwianRpIjoiODQzZThiMWItYzdmNS00NTkxLWI1NWQtYWYzYTc0Yjk1OWQ3IiwiaXNzIjoiQUVNRVQiLCJpYXQiOjE2MzEwNTQ2MDksInVzZXJJZCI6Ijg0M2U4YjFiLWM3ZjUtNDU5MS1iNTVkLWFmM2E3NGI5NTlkNyIsInJvbGUiOiIifQ.TXZIXy-nX75cjtqD3932b8zYCQt_OW72vHIBXpFS-vA"
url = "https://opendata.aemet.es/opendata/api/observacion/convencional/datos/estacion/2462"


############################### Paso 1 ##########################
querystring = {"api_key":api_key}
response = requests.get( url,  params=querystring)

# convertirmos a formato JSON para obtener los datos
respuesta = json.loads(response.text)
print("Respuesta paso 1", respuesta)

############################### Paso 2 ####################
pet_datos = requests.get(respuesta['datos'])
valores_datos = json.loads(pet_datos.text)
print("Datos: ")
pprint.pprint(valores_datos)

# para entender los datos mostramos los metadatos
pet_metadatos = requests.get(respuesta['metadatos'])
valores_metadatos = dict(json.loads(pet_metadatos.text))
print("="*50)
print("Metadatos: ")
pprint.pprint(valores_metadatos)
# Out:
# Respuesta paso 1 {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/5ddc64ee', 'metadatos': 'https://opendata.aemet.es/opendata/sh/55c2971b'}
# Datos:
# [{'alt': 1894.0,
#   'dmax': 12.0,
#   'dmaxu': 15.0,
#   'dv': 297.0,
#   'dvu': 309.0,
#   'fint': '2022-09-19T15:00:00',
#   'geo850': {'present': True, 'value': 1535.6},
#   'hr': 82.0,
#   'idema': '2462',
#   'inso': 7.0,
#   'lat': 40.793056,
#   'lon': -4.010556,
#   'nieve': 59.0,
#   'pacutp': 0.0,
#   'prec': 0.0,
#   'pres': 815.5,
#   'stddv': 42.0,
#   'stddvu': 41.0,
#   'stdvv': 0.4,
#   'stdvvu': 0.3,
#   'ta': 14.5,
#   'tamax': 14.5,
#   'tamin': 12.3,
#   'tpr': 11.4,
#   'ts': 16.7,
#   'tss20cm': 15.3,
#   'tss5cm': 15.2,
#   'ubi': 'NAVACERRADA PUERTO',
#   'vis': 20.0,
#   'vmax': 3.0,
#   'vmaxu': 2.9,
#   'vv': 0.5,
#   'vvu': 0.7},
#  {'alt': 1894.0,
#   'dmax': 31.0,
#   'dmaxu': 33.0,
#   'dv': 39.0,
#   'dvu': 46.0,
#   'fint': '2022-09-19T16:00:00',
#   'geo850': {'present': True, 'value': 1534.5},
#   'hr': 71.0,
#   'idema': '2462',
#   'inso': 24.2,
#   'lat': 40.793056,
#   'lon': -4.010556,
#   'nieve': 63.0,
#   'pacutp': 0.01,
#   'prec': 0.0,
#   'pres': 815.5,
#   'stddv': 22.0,
#   'stddvu': 31.0,
#   'stdvv': 0.8,
#   'stdvvu': 0.5,
#   'ta': 15.5,
#   'tamax': 15.5,
#   'tamin': 14.5,
#   'tpr': 10.3,
#   'ts': 16.7,
#   'tss20cm': 15.3,
#   'tss5cm': 15.3,
#   'ubi': 'NAVACERRADA PUERTO',
#   'vis': 20.0,
#   'vmax': 2.8,
#   'vmaxu': 2.7,
#   'vv': 1.1,
#   'vvu': 1.2},
#  {'alt': 1894.0,
#   'dmax': 61.0,
#   'dmaxu': 75.0,
#   'dv': 56.0,
#   'dvu': 63.0,
#   'fint': '2022-09-19T17:00:00',
#   'geo850': {'present': True, 'value': 1537.5},
#   'hr': 74.0,
#   'idema': '2462',
#   'inso': 6.9,
#   'lat': 40.793056,
#   'lon': -4.010556,
#   'nieve': 73.0,
#   'pacutp': 0.08,
#   'prec': 0.0,
#   'pres': 815.6,
#   'stddv': 15.0,
#   'stddvu': 16.0,
#   'stdvv': 1.0,
#   'stdvvu': 0.9,
#   'ta': 14.0,
#   'tamax': 15.5,
#   'tamin': 14.0,
#   'tpr': 9.4,
#   'ts': 14.2,
#   'tss20cm': 15.4,
#   'tss5cm': 15.4,
#   'ubi': 'NAVACERRADA PUERTO',
#   'vis': 20.0,
#   'vmax': 5.2,
#   'vmaxu': 5.5,
#   'vv': 2.6,
#   'vvu': 2.6},
#  {'alt': 1894.0,
#   'dmax': 48.0,
#   'dmaxu': 58.0,
#   'dv': 45.0,
#   'dvu': 51.0,
#   'fint': '2022-09-19T18:00:00',
#   'geo850': {'present': True, 'value': 1540.6},
#   'hr': 74.0,
#   'idema': '2462',
#   'inso': 9.5,
#   'lat': 40.793056,
#   'lon': -4.010556,
#   'nieve': 63.0,
#   'pacutp': 0.0,
#   'prec': 0.0,
#   'pres': 815.8,
#   'stddv': 9.0,
#   'stddvu': 10.0,
#   'stdvv': 0.4,
#   'stdvvu': 0.2,
#   'ta': 13.2,
#   'tamax': 14.1,
#   'tamin': 13.2,
#   'tpr': 8.7,
#   'ts': 12.6,
#   'tss20cm': 15.5,
#   'tss5cm': 15.4,
#   'ubi': 'NAVACERRADA PUERTO',
#   'vis': 20.0,
#   'vmax': 3.3,
#   'vmaxu': 3.1,
#   'vv': 2.2,
#   'vvu': 2.2},
#  {'alt': 1894.0,
#   'dmax': 81.0,
#   'dmaxu': 80.0,
#   'dv': 79.0,
#   'dvu': 86.0,
#   'fint': '2022-09-19T19:00:00',
#   'geo850': {'present': True, 'value': 1543.2},
#   'hr': 73.0,
#   'idema': '2462',
#   'inso': 0.0,
#   'lat': 40.793056,
#   'lon': -4.010556,
#   'nieve': 61.0,
#   'pacutp': 0.0,
#   'prec': 0.0,
#   'pres': 816.0,
#   'stddv': 14.0,
#   'stddvu': 15.0,
#   'stdvv': 0.7,
#   'stdvvu': 0.6,
#   'ta': 12.9,
#   'tamax': 13.2,
#   'tamin': 12.9,
#   'tpr': 8.1,
#   'ts': 11.7,
#   'tss20cm': 15.4,
#   'tss5cm': 15.3,
#   'ubi': 'NAVACERRADA PUERTO',
#   'vis': 20.0,
#   'vmax': 4.5,
#   'vmaxu': 4.6,
#   'vv': 2.3,
#   'vvu': 2.6},
#  {'alt': 1894.0,
#   'dmax': 61.0,
#   'dmaxu': 120.0,
#   'dv': 64.0,
#   'dvu': 74.0,
#   'fint': '2022-09-19T20:00:00',
#   'geo850': {'present': True, 'value': 1548.2},
#   'hr': 68.0,
#   'idema': '2462',
#   'inso': 0.0,
#   'lat': 40.793056,
#   'lon': -4.010556,
#   'nieve': 64.0,
#   'pacutp': 0.0,
#   'prec': 0.0,
#   'pres': 816.5,
#   'stddv': 43.0,
#   'stddvu': 66.0,
#   'stdvv': 1.1,
#   'stdvvu': 0.6,
#   'ta': 13.1,
#   'tamax': 13.1,
#   'tamin': 12.9,
#   'tpr': 7.3,
#   'ts': 12.0,
#   'tss20cm': 15.4,
#   'tss5cm': 15.2,
#   'ubi': 'NAVACERRADA PUERTO',
#   'vis': 20.0,
#   'vmax': 4.6,
#   'vmaxu': 4.9,
#   'vv': 1.0,
#   'vvu': 1.5},
#  {'alt': 1894.0,
#   'dmax': 287.0,
#   'dmaxu': 318.0,
#   'dv': 300.0,
#   'dvu': 305.0,
#   'fint': '2022-09-19T21:00:00',
#   'geo850': {'present': True, 'value': 1553.3},
#   'hr': 77.0,
#   'idema': '2462',
#   'inso': 0.0,
#   'lat': 40.793056,
#   'lon': -4.010556,
#   'nieve': 63.0,
#   'pacutp': 0.24,
#   'prec': 0.2,
#   'pres': 817.0,
#   'stddv': 12.0,
#   'stddvu': 13.0,
#   'stdvv': 1.0,
#   'stdvvu': 0.7,
#   'ta': 13.0,
#   'tamax': 13.6,
#   'tamin': 13.0,
#   'tpr': 9.0,
#   'ts': 12.1,
#   'tss20cm': 15.3,
#   'tss5cm': 15.1,
#   'ubi': 'NAVACERRADA PUERTO',
#   'vis': 10.6,
#   'vmax': 4.9,
#   'vmaxu': 4.9,
#   'vv': 3.3,
#   'vvu': 3.4},
#  {'alt': 1894.0,
#   'dmax': 148.0,
#   'dmaxu': 158.0,
#   'dv': 154.0,
#   'dvu': 161.0,
#   'fint': '2022-09-19T22:00:00',
#   'geo850': {'present': True, 'value': 1556.3},
#   'hr': 90.0,
#   'idema': '2462',
#   'inso': 0.0,
#   'lat': 40.793056,
#   'lon': -4.010556,
#   'nieve': 60.0,
#   'pacutp': 1.59,
#   'prec': 1.6,
#   'pres': 817.1,
#   'stddv': 9.0,
#   'stddvu': 10.0,
#   'stdvv': 0.7,
#   'stdvvu': 0.4,
#   'ta': 11.3,
#   'tamax': 13.0,
#   'tamin': 11.3,
#   'tpr': 9.7,
#   'ts': 11.8,
#   'tss20cm': 15.2,
#   'tss5cm': 15.0,
#   'ubi': 'NAVACERRADA PUERTO',
#   'vis': 7.4,
#   'vmax': 5.0,
#   'vmaxu': 4.9,
#   'vv': 3.8,
#   'vvu': 3.8},
#  {'alt': 1894.0,
#   'dmax': 124.0,
#   'dmaxu': 123.0,
#   'dv': 93.0,
#   'dvu': 98.0,
#   'fint': '2022-09-19T23:00:00',
#   'geo850': {'present': True, 'value': 1554.2},
#   'hr': 91.0,
#   'idema': '2462',
#   'inso': 0.0,
#   'lat': 40.793056,
#   'lon': -4.010556,
#   'nieve': 54.0,
#   'pacutp': 1.34,
#   'prec': 1.4,
#   'pres': 816.8,
#   'stddv': 21.0,
#   'stddvu': 28.0,
#   'stdvv': 1.7,
#   'stdvvu': 1.1,
#   'ta': 10.5,
#   'tamax': 11.3,
#   'tamin': 10.5,
#   'tpr': 9.0,
#   'ts': 11.3,
#   'tss20cm': 15.1,
#   'tss5cm': 14.9,
#   'ubi': 'NAVACERRADA PUERTO',
#   'vis': 13.2,
#   'vmax': 7.0,
#   'vmaxu': 7.0,
#   'vv': 2.8,
#   'vvu': 3.5},
#  {'alt': 1894.0,
#   'dmax': 123.0,
#   'dmaxu': 128.0,
#   'dv': 144.0,
#   'dvu': 151.0,
#   'fint': '2022-09-20T00:00:00',
#   'geo850': {'present': True, 'value': 1552.9},
#   'hr': 89.0,
#   'idema': '2462',
#   'inso': 0.0,
#   'lat': 40.793056,
#   'lon': -4.010556,
#   'nieve': 54.0,
#   'pacutp': 0.27,
#   'prec': 0.4,
#   'pres': 816.7,
#   'stddv': 13.0,
#   'stddvu': 15.0,
#   'stdvv': 1.6,
#   'stdvvu': 1.0,
#   'ta': 10.7,
#   'tamax': 10.7,
#   'tamin': 10.4,
#   'tpr': 8.9,
#   'ts': 10.9,
#   'tss20cm': 15.0,
#   'tss5cm': 14.8,
#   'ubi': 'NAVACERRADA PUERTO',
#   'vis': 20.0,
#   'vmax': 8.8,
#   'vmaxu': 9.0,
#   'vv': 5.5,
#   'vvu': 5.5},
#  {'alt': 1894.0,
#   'dmax': 142.0,
#   'dmaxu': 150.0,
#   'dv': 77.0,
#   'dvu': 85.0,
#   'fint': '2022-09-20T01:00:00',
#   'geo850': {'present': True, 'value': 1547.5},
#   'hr': 85.0,
#   'idema': '2462',
#   'inso': 0.0,
#   'lat': 40.793056,
#   'lon': -4.010556,
#   'nieve': 54.0,
#   'pacutp': 0.0,
#   'prec': 0.0,
#   'pres': 816.2,
#   'stddv': 17.0,
#   'stddvu': 11.0,
#   'stdvv': 0.9,
#   'stdvvu': 0.5,
#   'ta': 11.0,
#   'tamax': 11.0,
#   'tamin': 10.7,
#   'tpr': 8.5,
#   'ts': 11.3,
#   'tss20cm': 14.9,
#   'tss5cm': 14.7,
#   'ubi': 'NAVACERRADA PUERTO',
#   'vis': 20.0,
#   'vmax': 7.8,
#   'vmaxu': 7.7,
#   'vv': 2.8,
#   'vvu': 3.1},
#  {'alt': 1894.0,
#   'dmax': 92.0,
#   'dmaxu': 55.0,
#   'dv': 100.0,
#   'dvu': 103.0,
#   'fint': '2022-09-20T02:00:00',
#   'geo850': {'present': True, 'value': 1547.3},
#   'hr': 85.0,
#   'idema': '2462',
#   'inso': 0.0,
#   'lat': 40.793056,
#   'lon': -4.010556,
#   'nieve': 54.0,
#   'pacutp': 0.0,
#   'prec': 0.0,
#   'pres': 816.2,
#   'stddv': 34.0,
#   'stddvu': 29.0,
#   'stdvv': 1.2,
#   'stdvvu': 0.6,
#   'ta': 11.1,
#   'tamax': 11.1,
#   'tamin': 11.0,
#   'tpr': 8.7,
#   'ts': 11.5,
#   'tss20cm': 14.8,
#   'tss5cm': 14.6,
#   'ubi': 'NAVACERRADA PUERTO',
#   'vis': 20.0,
#   'vmax': 5.2,
#   'vmaxu': 5.7,
#   'vv': 1.4,
#   'vvu': 1.7},
#  {'alt': 1894.0,
#   'dmax': 63.0,
#   'dmaxu': 68.0,
#   'dv': 31.0,
#   'dvu': 37.0,
#   'fint': '2022-09-20T03:00:00',
#   'geo850': {'present': True, 'value': 1546.1},
#   'hr': 81.0,
#   'idema': '2462',
#   'inso': 0.0,
#   'lat': 40.793056,
#   'lon': -4.010556,
#   'nieve': 54.0,
#   'pacutp': 0.0,
#   'prec': 0.0,
#   'pres': 816.1,
#   'stddv': 6.0,
#   'stddvu': 7.0,
#   'stdvv': 0.3,
#   'stdvvu': 0.2,
#   'ta': 11.3,
#   'tamax': 11.3,
#   'tamin': 11.1,
#   'tpr': 8.1,
#   'ts': 10.9,
#   'tss20cm': 14.7,
#   'tss5cm': 14.5,
#   'ubi': 'NAVACERRADA PUERTO',
#   'vis': 20.0,
#   'vmax': 4.6,
#   'vmaxu': 5.2,
#   'vv': 1.7,
#   'vvu': 1.7},
#  {'alt': 1894.0,
#   'dmax': 56.0,
#   'dmaxu': 68.0,
#   'dv': 45.0,
#   'dvu': 51.0,
#   'fint': '2022-09-20T04:00:00',
#   'geo850': {'present': True, 'value': 1544.8},
#   'hr': 85.0,
#   'idema': '2462',
#   'inso': 0.0,
#   'lat': 40.793056,
#   'lon': -4.010556,
#   'nieve': 55.0,
#   'pacutp': 0.0,
#   'prec': 0.0,
#   'pres': 815.9,
#   'stddv': 13.0,
#   'stddvu': 13.0,
#   'stdvv': 0.4,
#   'stdvvu': 0.3,
#   'ta': 10.7,
#   'tamax': 11.3,
#   'tamin': 10.7,
#   'tpr': 8.3,
#   'ts': 10.1,
#   'tss20cm': 14.6,
#   'tss5cm': 14.4,
#   'ubi': 'NAVACERRADA PUERTO',
#   'vis': 20.0,
#   'vmax': 3.5,
#   'vmaxu': 3.6,
#   'vv': 2.2,
#   'vvu': 2.1},
#  {'alt': 1894.0,
#   'dmax': 336.0,
#   'dmaxu': 340.0,
#   'dv': 355.0,
#   'dvu': 2.0,
#   'fint': '2022-09-20T05:00:00',
#   'geo850': {'present': True, 'value': 1543.1},
#   'hr': 83.0,
#   'idema': '2462',
#   'inso': 0.0,
#   'lat': 40.793056,
#   'lon': -4.010556,
#   'nieve': 60.0,
#   'pacutp': 0.0,
#   'prec': 0.0,
#   'pres': 815.8,
#   'stddv': 10.0,
#   'stddvu': 169.0,
#   'stdvv': 0.7,
#   'stdvvu': 0.5,
#   'ta': 11.2,
#   'tamax': 11.2,
#   'tamin': 10.7,
#   'tpr': 8.4,
#   'ts': 10.0,
#   'tss20cm': 14.5,
#   'tss5cm': 14.3,
#   'ubi': 'NAVACERRADA PUERTO',
#   'vis': 20.0,
#   'vmax': 5.0,
#   'vmaxu': 4.8,
#   'vv': 3.3,
#   'vvu': 3.4},
#  {'alt': 1894.0,
#   'dmax': 335.0,
#   'dmaxu': 340.0,
#   'dv': 358.0,
#   'dvu': 4.0,
#   'fint': '2022-09-20T06:00:00',
#   'geo850': {'present': True, 'value': 1545.3},
#   'hr': 81.0,
#   'idema': '2462',
#   'inso': 0.0,
#   'lat': 40.793056,
#   'lon': -4.010556,
#   'nieve': 60.0,
#   'pacutp': 0.0,
#   'prec': 0.0,
#   'pres': 816.0,
#   'stddv': 8.0,
#   'stddvu': 11.0,
#   'stdvv': 0.6,
#   'stdvvu': 0.5,
#   'ta': 11.1,
#   'tamax': 11.3,
#   'tamin': 11.1,
#   'tpr': 8.0,
#   'ts': 9.9,
#   'tss20cm': 14.4,
#   'tss5cm': 14.2,
#   'ubi': 'NAVACERRADA PUERTO',
#   'vis': 20.0,
#   'vmax': 5.1,
#   'vmaxu': 5.0,
#   'vv': 3.3,
#   'vvu': 3.2},
#  {'alt': 1894.0,
#   'dmax': 341.0,
#   'dmaxu': 5.0,
#   'dv': 322.0,
#   'dvu': 327.0,
#   'fint': '2022-09-20T07:00:00',
#   'geo850': {'present': True, 'value': 1549.2},
#   'hr': 83.0,
#   'idema': '2462',
#   'inso': 26.8,
#   'lat': 40.793056,
#   'lon': -4.010556,
#   'nieve': 58.0,
#   'pacutp': 0.0,
#   'prec': 0.0,
#   'pres': 816.4,
#   'stddv': 6.0,
#   'stddvu': 7.0,
#   'stdvv': 0.4,
#   'stdvvu': 0.3,
#   'ta': 11.3,
#   'tamax': 11.3,
#   'tamin': 11.1,
#   'tpr': 8.5,
#   'ts': 10.6,
#   'tss20cm': 14.3,
#   'tss5cm': 14.1,
#   'ubi': 'NAVACERRADA PUERTO',
#   'vis': 20.0,
#   'vmax': 5.1,
#   'vmaxu': 5.2,
#   'vv': 2.9,
#   'vvu': 2.9},
#  {'alt': 1894.0,
#   'dmax': 340.0,
#   'dmaxu': 340.0,
#   'dv': 349.0,
#   'dvu': 355.0,
#   'fint': '2022-09-20T08:00:00',
#   'geo850': {'present': True, 'value': 1550.2},
#   'hr': 77.0,
#   'idema': '2462',
#   'inso': 60.0,
#   'lat': 40.793056,
#   'lon': -4.010556,
#   'nieve': 59.0,
#   'pacutp': 0.0,
#   'prec': 0.0,
#   'pres': 816.7,
#   'stddv': 14.0,
#   'stddvu': 15.0,
#   'stdvv': 0.8,
#   'stdvvu': 0.5,
#   'ta': 13.0,
#   'tamax': 13.0,
#   'tamin': 11.3,
#   'tpr': 9.0,
#   'ts': 15.4,
#   'tss20cm': 14.2,
#   'tss5cm': 14.0,
#   'ubi': 'NAVACERRADA PUERTO',
#   'vis': 20.0,
#   'vmax': 4.3,
#   'vmaxu': 4.2,
#   'vv': 1.9,
#   'vvu': 1.9},
#  {'alt': 1894.0,
#   'dmax': 263.0,
#   'dmaxu': 260.0,
#   'dv': 6.0,
#   'dvu': 15.0,
#   'fint': '2022-09-20T09:00:00',
#   'geo850': {'present': True, 'value': 1553.9},
#   'hr': 69.0,
#   'idema': '2462',
#   'inso': 60.0,
#   'lat': 40.793056,
#   'lon': -4.010556,
#   'nieve': 66.0,
#   'pacutp': 0.0,
#   'prec': 0.0,
#   'pres': 817.3,
#   'stddv': 30.0,
#   'stddvu': 34.0,
#   'stdvv': 0.5,
#   'stdvvu': 0.3,
#   'ta': 15.1,
#   'tamax': 15.1,
#   'tamin': 13.0,
#   'tpr': 9.4,
#   'ts': 18.9,
#   'tss20cm': 14.2,
#   'tss5cm': 14.0,
#   'ubi': 'NAVACERRADA PUERTO',
#   'vis': 20.0,
#   'vmax': 2.8,
#   'vmaxu': 2.7,
#   'vv': 0.9,
#   'vvu': 1.0},
#  {'alt': 1894.0,
#   'dmax': 9.0,
#   'dmaxu': 288.0,
#   'dv': 340.0,
#   'dvu': 344.0,
#   'fint': '2022-09-20T10:00:00',
#   'geo850': {'present': True, 'value': 1554.2},
#   'hr': 64.0,
#   'idema': '2462',
#   'inso': 60.0,
#   'lat': 40.793056,
#   'lon': -4.010556,
#   'nieve': 86.0,
#   'pacutp': 0.0,
#   'prec': 0.0,
#   'pres': 817.5,
#   'stddv': 37.0,
#   'stddvu': 40.0,
#   'stdvv': 0.7,
#   'stdvvu': 0.4,
#   'ta': 16.7,
#   'tamax': 16.7,
#   'tamin': 15.1,
#   'tpr': 9.8,
#   'ts': 22.9,
#   'tss20cm': 14.2,
#   'tss5cm': 14.2,
#   'ubi': 'NAVACERRADA PUERTO',
#   'vis': 20.0,
#   'vmax': 2.4,
#   'vmaxu': 2.5,
#   'vv': 1.1,
#   'vvu': 1.2},
#  {'alt': 1894.0,
#   'dmax': 264.0,
#   'dmaxu': 263.0,
#   'dv': 311.0,
#   'dvu': 316.0,
#   'fint': '2022-09-20T11:00:00',
#   'geo850': {'present': True, 'value': 1554.6},
#   'hr': 64.0,
#   'idema': '2462',
#   'inso': 60.0,
#   'lat': 40.793056,
#   'lon': -4.010556,
#   'nieve': 66.0,
#   'pacutp': 0.0,
#   'prec': 0.0,
#   'pres': 817.6,
#   'stddv': 32.0,
#   'stddvu': 34.0,
#   'stdvv': 1.4,
#   'stdvvu': 0.9,
#   'ta': 17.2,
#   'tamax': 17.2,
#   'tamin': 16.7,
#   'tpr': 10.3,
#   'ts': 22.2,
#   'tss20cm': 14.4,
#   'tss5cm': 14.5,
#   'ubi': 'NAVACERRADA PUERTO',
#   'vis': 19.1,
#   'vmax': 5.5,
#   'vmaxu': 5.2,
#   'vv': 2.4,
#   'vvu': 2.6},
#  {'alt': 1894.0,
#   'dmax': 319.0,
#   'dmaxu': 328.0,
#   'dv': 324.0,
#   'dvu': 330.0,
#   'fint': '2022-09-20T12:00:00',
#   'geo850': {'present': True, 'value': 1551.9},
#   'hr': 54.0,
#   'idema': '2462',
#   'inso': 60.0,
#   'lat': 40.793056,
#   'lon': -4.010556,
#   'nieve': 63.0,
#   'pacutp': 0.0,
#   'prec': 0.0,
#   'pres': 817.4,
#   'stddv': 25.0,
#   'stddvu': 30.0,
#   'stdvv': 1.6,
#   'stdvvu': 1.3,
#   'ta': 17.9,
#   'tamax': 18.1,
#   'tamin': 17.2,
#   'tpr': 8.4,
#   'ts': 22.4,
#   'tss20cm': 14.7,
#   'tss5cm': 14.9,
#   'ubi': 'NAVACERRADA PUERTO',
#   'vis': 20.0,
#   'vmax': 7.1,
#   'vmaxu': 6.7,
#   'vv': 2.8,
#   'vvu': 2.9},
#  {'alt': 1894.0,
#   'dmax': 347.0,
#   'dmaxu': 348.0,
#   'dv': 314.0,
#   'dvu': 320.0,
#   'fint': '2022-09-20T13:00:00',
#   'geo850': {'present': True, 'value': 1548.4},
#   'hr': 52.0,
#   'idema': '2462',
#   'inso': 60.0,
#   'lat': 40.793056,
#   'lon': -4.010556,
#   'nieve': 61.0,
#   'pacutp': 0.0,
#   'prec': 0.0,
#   'pres': 817.2,
#   'stddv': 40.0,
#   'stddvu': 53.0,
#   'stdvv': 1.6,
#   'stdvvu': 1.1,
#   'ta': 19.0,
#   'tamax': 19.0,
#   'tamin': 17.7,
#   'tpr': 8.9,
#   'ts': 22.8,
#   'tss20cm': 15.0,
#   'tss5cm': 15.2,
#   'ubi': 'NAVACERRADA PUERTO',
#   'vis': 20.0,
#   'vmax': 7.1,
#   'vmaxu': 7.0,
#   'vv': 1.8,
#   'vvu': 2.2}]
# ==================================================
# Metadatos:
# {'campos': [{'descripcion': 'Indicativo climatógico de la estación '
#                             'meteorológia automática',
#              'id': 'idema',
#              'requerido': True,
#              'tipo_datos': 'string'},
#             {'descripcion': 'Longitud de la estación meteorológica (grados)',
#              'id': 'lon',
#              'requerido': True,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Latitud de la estación meteorológica (grados)',
#              'id': 'lat',
#              'requerido': True,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Altitud de la estación en metros',
#              'id': 'alt',
#              'requerido': True,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Ubicación de la estación. Nombre de la estación',
#              'id': 'ubi',
#              'requerido': True,
#              'tipo_datos': 'string'},
#             {'descripcion': 'Fecha hora final del período de observación, se '
#                             'trata de datos del periodo de la hora anterior a '
#                             'la indicada por este campo (hora UTC)',
#              'id': 'fint',
#              'requerido': False,
#              'tipo_datos': 'string (AAAA-MM-DDTHH:MM:SS)'},
#             {'descripcion': 'Precipitación acumulada, medida por el '
#                             'pluviómetro, durante los 60 minutos anteriores a '
#                             'la hora indicada por el período de observación '
#                             "'fint' (mm, equivalente a l/m2)",
#              'id': 'prec',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Precipitación acumulada, medida por el '
#                             'disdrómetro, durante los 60 minutos anteriores a '
#                             'la hora indicada por el período de observación '
#                             "'fint' (mm, equivalente a l/m2)",
#              'id': 'pacutp',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Precipitación líquida acumulada durante los 60 '
#                             'minutos anteriores a la hora indicada por el '
#                             "período de observación 'fint' (mm, equivalente a "
#                             'l/m2)',
#              'id': 'pliqtp',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Precipitación sólida acumulada durante los 60 '
#                             'minutos anteriores a la hora indicada por el '
#                             "período de observación 'fint' (mm, equivalente a "
#                             'l/m2)',
#              'id': 'psolt',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Velocidad máxima del viento, valor máximo del '
#                             'viento mantenido 3 segundos y registrado en los '
#                             '60 minutos anteriores a la hora indicada por el '
#                             "período de observación 'fint' (m/s)",
#              'id': 'vmax',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Velocidad media del viento, media escalar de las '
#                             'muestras adquiridas cada 0,25 ó 1 segundo en el '
#                             'período de 10 minutos anterior al indicado por '
#                             "'fint' (m/s)",
#              'id': 'vv',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Velocidad máxima del viento (sensor ultrasónico), '
#                             'valor máximo del viento mantenido 3 segundos y '
#                             'registrado en los 60 minutos anteriores a la hora '
#                             "indicada por el período de observación 'fint' "
#                             '(m/s)',
#              'id': 'vmaxu',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Velocidad media del viento (sensor ultrasónico), '
#                             'media escalar en el periódo de 10 minutos '
#                             "anterior al indicado por 'fint' de las muestras "
#                             'adquiridas cada 0,25 ó 1 segundo (m/s)',
#              'id': 'vvu',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Dirección media del viento, en el período de 10 '
#                             "minutos anteriores a la fecha indicada por 'fint' "
#                             '(grados)',
#              'id': 'dv',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Dirección media del viento (sensor ultrasónico), '
#                             'en el período de 10 minutos anteriores a la fecha '
#                             "indicada por 'fint' (grados)",
#              'id': 'dvu',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Dirección del viento máximo registrado en los 60 '
#                             "minutos anteriores a la hora indicada por 'fint' "
#                             '(grados)',
#              'id': 'dmax',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Dirección del viento máximo registrado en los 60 '
#                             "minutos anteriores a la hora indicada por 'fint' "
#                             'por el sensor ultrasónico (grados)',
#              'id': 'dmaxu',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Desviación estándar de las muestras adquiridas de '
#                             'velocidad del viento durante los 10 minutos '
#                             "anteriores a la fecha dada por 'fint' (m/s)",
#              'id': 'stdvv',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Desviación estándar de las muestras adquiridas de '
#                             'la dirección del viento durante los 10 minutos '
#                             "anteriores a la fecha dada por 'fint' (grados)",
#              'id': 'stddv',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Desviación estándar de las muestras adquiridas de '
#                             'velocidad del viento durante los 10 minutos '
#                             "anteriores a la fecha dada por 'fint' obtenido "
#                             'del sensor ultrasónico de viento instalado junto '
#                             'al convencional (m/s)',
#              'id': 'stdvvu',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Desviación estándar de las muestras adquiridas de '
#                             'la dirección del viento durante los 10 minutos '
#                             "anteriores a la fecha dada por 'fint' obtenido "
#                             'del sensor ultrasónico de viento instalado junto '
#                             'al convencional (grados)',
#              'id': 'stddvu',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Humedad relativa instantánea del aire '
#                             "correspondiente a la fecha dada por 'fint' (%)",
#              'id': 'hr',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Duración de la insolación durante los 60 minutos '
#                             'anteriores a la hora indicada por el período de '
#                             "observación 'fint' (horas)",
#              'id': 'inso',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Presión instantánea al nivel en el que se '
#                             'encuentra instalado el barómetro y '
#                             "correspondiente a la fecha dada por 'fint' (hPa)",
#              'id': 'pres',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Valor de la presión reducido al nivel del mar '
#                             'para aquellas estaciones cuya altitud es igual o '
#                             'menor a 750 metros y correspondiente a la fecha '
#                             "indicada por 'fint' (hPa)",
#              'id': 'pres_nmar',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Temperatura suelo, temperatura instantánea junto '
#                             'al suelo y correspondiente a los 10 minutos '
#                             "anteriores a la fecha dada por 'fint' (grados "
#                             'Celsius)',
#              'id': 'ts',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Temperatura subsuelo 20 cm, temperatura del '
#                             'subsuelo a una profundidad de 20 cm y '
#                             'correspondiente a los 10 minutos anteriores a la '
#                             "fecha dada por 'fint' (grados Celsius)",
#              'id': 'tss20cm',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Temperatura subsuelo 5 cm, temperatura del '
#                             'subsuelo a una profundidad de 5 cm y '
#                             'correspondiente a los 10 minutos anteriores a la '
#                             "fecha dada por 'fint' (grados Celsius)",
#              'id': 'tss5cm',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Temperatura instantánea del aire correspondiente '
#                             "a la fecha dada por 'fint' (grados Celsius)",
#              'id': 'ta',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Temperatura del punto de rocío calculado '
#                             "correspondiente a la fecha 'fint' (grados "
#                             'Celsius)',
#              'id': 'tpr',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Temperatura mínima del aire, valor mínimo de los '
#                             "60 valores instantáneos de 'ta' medidos en el "
#                             'período de 60 minutos anteriores a la hora '
#                             "indicada por el período de observación 'fint' "
#                             '(grados Celsius)',
#              'id': 'tamin',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Temperatura máxima del aire, valor máximo de los '
#                             "60 valores instantáneos de 'ta' medidos en el "
#                             'período de 60 minutos anteriores a la hora '
#                             "indicada por el período de observación 'fint' "
#                             '(grados Celsius)',
#              'id': 'tamax',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Visibilidad, promedio de la medida de la '
#                             'visibilidad correspondiente a los 10 minutos '
#                             "anteriores a la fecha dada por 'fint' (Km)",
#              'id': 'vis',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Altura del nivel de la superficie de referencia '
#                             'barométrica de 700 hPa calculado para las '
#                             'estaciones con altitud mayor de 2300 metros y '
#                             "correspondiente a la fecha indicada por 'fint' (m "
#                             'geopotenciales)',
#              'id': 'geo700',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Altura del nivel de la superficie de referencia '
#                             'barométrica de 850 hPa calculado para las '
#                             'estaciones con altitud mayor de 1000 metros y '
#                             'menor o igual a 2300 metros y correspondiente a '
#                             "la fecha indicada por 'fint' (m geopotenciales)",
#              'id': 'geo850',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Altura del nivel de la superficie barométrica de '
#                             '925 hPa calculado para las estaciones con altitud '
#                             'mayor de 750 metros y y menor o igual a 1000 '
#                             'metros correspondiente a la fecha indicada por '
#                             "'fint' (m geopotenciales)",
#              'id': 'geo925',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Recorrido del viento durante los 60 minutos '
#                             "anteriores a la fecha indicada por 'fint' (Hm)",
#              'id': 'rviento',
#              'requerido': False,
#              'tipo_datos': 'float'},
#             {'descripcion': 'Espesor de la capa de nieve medid en los 10 '
#                             'minutos anteriores a la a la fecha indicada por '
#                             "'fint' (cm)",
#              'id': 'nieve',
#              'requerido': False,
#              'tipo_datos': 'float'}],
#  'copyright': '© AEMET. Autorizado el uso de la información y su reproducción '
#               'citando a AEMET como autora de la misma.',
#  'formato': 'application/json',
#  'notaLegal': 'http://www.aemet.es/es/nota_legal',
#  'periodicidad': 'continuamente',
#  'unidad_generadora': 'Servicio de Observación'}

# %% [markdown]
# Para entender los datos podemos consultar los metadatos

# %%
# para entender los datos mostramos los metadatos
pet_metadatos = requests.get(respuesta['metadatos'])
valores_metadatos = dict(json.loads(pet_metadatos.text))
print("="*50)
print("Metadatos: ")
pprint.pprint(valores_metadatos)

# %% [markdown]
# **Ejercicio 3**
# Para obtener dos datos con esta API solo tenemos que cambiar la URL. Por ejemplo la siguiente URL nos permite obtener datos históricos de un día y estación concretos. Completar los dos pasos para obtener el resultado

# %%
import json # para convertir string a JSON
import requests # para descargar ficheros
import pprint # para mostrar JSON en "bonito"


api_key = "eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJyYWZhY3JAdWNtLmVzIiwianRpIjoiODQzZThiMWItYzdmNS00NTkxLWI1NWQtYWYzYTc0Yjk1OWQ3IiwiaXNzIjoiQUVNRVQiLCJpYXQiOjE2MzEwNTQ2MDksInVzZXJJZCI6Ijg0M2U4YjFiLWM3ZjUtNDU5MS1iNTVkLWFmM2E3NGI5NTlkNyIsInJvbGUiOiIifQ.TXZIXy-nX75cjtqD3932b8zYCQt_OW72vHIBXpFS-vA"
url = "https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2021-01-06T00%3A00%3A00UTC/fechafin/2021-01-08T23%3A59%3A00UTC/estacion/3194U"
nombreFicheroDatos="2_ejercicio3_datos"
nombreFicheroMetadatos="2_ejercicio3_Metadatos"

############################### Paso 1 ##########################
parametros = {"api_key":api_key}
datos = requests.get( url,  params=parametros)
datos_json = json.loads(datos.text)
print("Datos obtenidos..:")
pprint.pprint(datos_json)
open(nombreFicheroDatos, "wb").write(datos.content)

############################### Paso 2 ##########################
metadatos = requests.get(datos_json['metadatos'])
valores_metadatos = dict(json.loads(metadatos.text))
print("="*50)
print("Metadatos: ")
pprint.pprint(valores_metadatos)
open(nombreFicheroMetadatos, "wb").write(metadatos.content)
# Out:
# Datos obtenidos..:
# {'datos': 'https://opendata.aemet.es/opendata/sh/4442db08',
#  'descripcion': 'exito',
#  'estado': 200,
#  'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# ==================================================
# Metadatos:
# {'campos': [{'descripcion': 'fecha del dia (AAAA-MM-DD)',
#              'id': 'fecha',
#              'requerido': True,
#              'tipo_datos': 'string'},
#             {'descripcion': 'indicativo climatológico',
#              'id': 'indicativo',
#              'requerido': True,
#              'tipo_datos': 'string'},
#             {'descripcion': 'nombre (ubicación) de la estación',
#              'id': 'nombre',
#              'requerido': True,
#              'tipo_datos': 'string'},
#             {'descripcion': 'provincia de la estación',
#              'id': 'provincia',
#              'requerido': True,
#              'tipo_datos': 'string'},
#             {'descripcion': 'altitud de la estación en m sobre el nivel del '
#                             'mar',
#              'id': 'altitud',
#              'requerido': True,
#              'tipo_datos': 'float',
#              'unidad': 'm'},
#             {'descripcion': 'Temperatura media diaria',
#              'id': 'tmed',
#              'requerido': False,
#              'tipo_datos': 'float',
#              'unidad': '°C'},
#             {'descripcion': 'Precipitación diaria de 07 a 07',
#              'id': 'prec',
#              'requerido': False,
#              'tipo_datos': 'float',
#              'unidad': 'mm (Ip = inferior a 0,1 mm) (Acum = Precipitación '
#                        'acumulada)'},
#             {'descripcion': 'Temperatura Mínima del día',
#              'id': 'tmin',
#              'requerido': False,
#              'tipo_datos': 'float',
#              'unidad': '°C'},
#             {'descripcion': 'Hora y minuto de la temperatura mínima',
#              'id': 'horatmin',
#              'requerido': False,
#              'tipo_datos': 'string',
#              'unidad': 'UTC'},
#             {'descripcion': 'Temperatura Máxima del día',
#              'id': 'tmax',
#              'requerido': False,
#              'tipo_datos': 'float',
#              'unidad': '°C'},
#             {'descripcion': 'Hora y minuto de la temperatura máxima',
#              'id': 'horatmax',
#              'requerido': False,
#              'tipo_datos': 'string',
#              'unidad': 'UTC'},
#             {'descripcion': 'Dirección de la racha máxima',
#              'id': 'dir',
#              'requerido': False,
#              'tipo_datos': 'float',
#              'unidad': 'decenas de grado (99 = dirección variable)(88 = sin '
#                        'dato)'},
#             {'descripcion': 'Velocidad media del viento',
#              'id': 'velmedia',
#              'requerido': False,
#              'tipo_datos': 'float',
#              'unidad': 'm/s'},
#             {'descripcion': 'Racha máxima del viento',
#              'id': 'racha',
#              'requerido': False,
#              'tipo_datos': 'float',
#              'unidad': 'm/s'},
#             {'descripcion': 'Hora y minuto de la racha máxima',
#              'id': 'horaracha',
#              'requerido': False,
#              'tipo_datos': 'string',
#              'unidad': 'UTC'},
#             {'descripcion': 'Insolación',
#              'id': 'sol',
#              'requerido': False,
#              'tipo_datos': 'float',
#              'unidad': 'horas'},
#             {'descripcion': 'Presión máxima al nivel de referencia de la '
#                             'estación',
#              'id': 'presmax',
#              'requerido': False,
#              'tipo_datos': 'float',
#              'unidad': 'hPa'},
#             {'descripcion': 'Hora de la presión máxima (redondeada a la hora '
#                             'entera más próxima)',
#              'id': 'horapresmax',
#              'requerido': False,
#              'tipo_datos': 'string',
#              'unidad': 'UTC'},
#             {'descripcion': 'Presión mínima al nivel de referencia de la '
#                             'estación',
#              'id': 'presmin',
#              'requerido': False,
#              'tipo_datos': 'float',
#              'unidad': 'hPa'},
#             {'descripcion': 'Hora de la presión mínima (redondeada a la hora '
#                             'entera más próxima)',
#              'id': 'horapresmin',
#              'requerido': False,
#              'tipo_datos': 'string',
#              'unidad': 'UTC'}],
#  'copyright': '© AEMET. Autorizado el uso de la información y su reproducción '
#               'citando a AEMET como autora de la misma.',
#  'descripcion': 'Climatologías diarias',
#  'formato': 'application/json',
#  'notaLegal': 'http://www.aemet.es/es/nota_legal',
#  'periodicidad': '1 vez al día, con un retardo de 4 días',
#  'unidad_generadora': 'Servicio del Banco Nacional de Datos Climatológicos'}
# 3866

# %% [markdown]
# <a name="Carga-de-ficheros-CSV-con-Pandas"></a>
# ### Carga de ficheros CSV con Pandas

# %% [markdown]
# [read_csv](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) y [read_excel](https://pythonbasics.org/read-excel/) permiten leer ficheros separados por un carácter y ficheros excel
# En ambos casos devuelven un dataframe: una tabla en Pandas que representa el conjunto de datos en memoria
#
#
# ##### read_csv
#
# El principal parámetro es la dirección donde se encuentra el fichero. Algunos parámetros comunes de read_csv
#
# - sep: el separador, por defecto “,”
# - Header: para indicar si la primera línea contiene la cabecera (por defecto True)
# - Thousands, decimal: separadores de miles y de decimales
# - encoding: codificación de caracteres. Deber ser una codificaciones estándar

# %%
import pandas as pd # normalmente pandas se renombra como pd
fichero = 'https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/madrid/contaminacionLargo.csv'

df = pd.read_csv(fichero)
df
# Out:
#           ANO  MES   DIA  HORA   CO     NO    NO2  PM2.5  PM10  NOx    O3  \
# 0      2019.0  1.0   1.0   1.0  0.6   81.0   73.0    NaN   NaN  196  3.08
# 1      2019.0  1.0   1.0   2.0  0.8  124.0   82.0    NaN   NaN  272  3.05
# 2      2019.0  1.0   1.0   3.0  0.7   93.0   72.0    NaN   NaN  215  3.13
# 3      2019.0  1.0   1.0   4.0  0.6   86.0   66.0    NaN   NaN  198  3.02
# 4      2019.0  1.0   1.0   5.0  0.6   79.0   64.0    NaN   NaN  185  2.98
# ...       ...  ...   ...   ...  ...    ...    ...    ...   ...  ...   ...
# 24021  2021.0  9.0  30.0  20.0  0.3   27.0   80.0   17.0  23.0  122   NaN
# 24022  2021.0  9.0  30.0  21.0  1.1  168.0  153.0   19.0  30.0  411   NaN
# 24023  2021.0  9.0  30.0  22.0  1.0  179.0  157.0   28.0  44.0  431   NaN
# 24024  2021.0  9.0  30.0  23.0  0.8  115.0  133.0   27.0  43.0  309   NaN
# 24025  2021.0  9.0  30.0  24.0  0.4   19.0  102.0   20.0  30.0  130   NaN
#
#                     fechaH                fecha    festivo
# 0      2019-01-01 00:00:00  2019-01-01 00:00:00    festivo
# 1      2019-01-01 01:00:00  2019-01-01 00:00:00    festivo
# 2      2019-01-01 02:00:00  2019-01-01 00:00:00    festivo
# 3      2019-01-01 03:00:00  2019-01-01 00:00:00    festivo
# 4      2019-01-01 04:00:00  2019-01-01 00:00:00    festivo
# ...                    ...                  ...        ...
# 24021  2021-09-30 19:00:00  2021-09-30 00:00:00  laborable
# 24022  2021-09-30 20:00:00  2021-09-30 00:00:00  laborable
# 24023  2021-09-30 21:00:00  2021-09-30 00:00:00  laborable
# 24024  2021-09-30 22:00:00  2021-09-30 00:00:00  laborable
# 24025  2021-09-30 23:00:00  2021-09-30 00:00:00  laborable
#
# [24026 rows x 14 columns]

# %% [markdown]
# El resultado es un dataframe; una tabla de pandas que utilizaremos como nuestro principal almacen de datos. Si el fichero no tiene el formato adecuado, por ejemplo, por la codificación, podemos obtener un error

# %%
#El codigo da error por no especificarse la codificación correcta
import pandas as pd
fichero = "https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/parocomunidades.csv"
df2 = pd.read_csv(fichero)

# %%
import pandas as pd
fichero = "https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/parocomunidades.csv"
df2 = pd.read_csv(fichero,encoding="latin1") # o cp1252
df2
# Out:
#      Comunidad  Periodo  Total
# 0    Andalucía     2019  20.80
# 1    Andalucía     2018  21.26
# 2    Andalucía     2017  24.43
# 3    Andalucía     2016  28.25
# 4    Andalucía     2015  29.83
# ..         ...      ...    ...
# 337    Melilla     2006   9.86
# 338    Melilla     2005  12.33
# 339    Melilla     2004  12.49
# 340    Melilla     2003  19.88
# 341    Melilla     2002   3.57
#
# [342 rows x 3 columns]

# %% [markdown]
# ##### to_csv
# La función de pandas [to_csv](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html#pandas.DataFrame.to_csv) permite grabar un dataframe en formato csv, debemos recordar 2 cosas principalmente:
# - se encuentra dentro del objeto dataframe, por eso pondremos df.to_csv, y no pd.to_csv
# - Conviene añadir el parámetro index=False para que no incluya el índice o número de línea

# %%
import pandas as pd
fichero = r".\parocomunidades.csv"
df2.to_csv(fichero, index=False, encoding="utf-8")

# %% [markdown]
# **Ejercicio 4**: cargar el fichero que acabamos de grabar y mostrarlo en el notebook

# %%
# solución
import pandas as pd
fichero = r".\parocomunidades.csv"

df3 = pd.read_csv(fichero)
df3
# Out:
#      Comunidad  Periodo  Total
# 0    Andalucía     2019  20.80
# 1    Andalucía     2018  21.26
# 2    Andalucía     2017  24.43
# 3    Andalucía     2016  28.25
# 4    Andalucía     2015  29.83
# ..         ...      ...    ...
# 337    Melilla     2006   9.86
# 338    Melilla     2005  12.33
# 339    Melilla     2004  12.49
# 340    Melilla     2003  19.88
# 341    Melilla     2002   3.57
#
# [342 rows x 3 columns]

# %% [markdown]
# <a name="Carga-de-ficheros-Excel-con-Pandas"></a>
# ### Carga de ficheros Excel con Pandas

# %% [markdown]
# ##### read_excel
# La lectura con pd.read_excel utiliza internamente otro librería `xlrd` que habra que instalar sino está en el sistema. Este ejemplo carga un fichero con valores bursátiles

# %%
import pandas as pd
fichero='https://github.com/RafaelCaballero/tdm/raw/master/datos/raw_open.xlsx'
df = pd.read_excel(fichero)
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /usr/local/lib/python3.9/dist-packages/pandas/compat/_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     137 try:
# --> 138     module = importlib.import_module(name)
#     139 except ImportError:
#
# File /usr/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:984, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In [51], line 3
#       1 import pandas as pd
#       2 fichero='https://github.com/RafaelCaballero/tdm/raw/master/datos/raw_open.xlsx'
# ----> 3 df = pd.read_excel(fichero)
#       4 df
#
# File /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.9/dist-packages/pandas/io/excel/_base.py:457, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     455 if not isinstance(io, ExcelFile):
#     456     should_close = True
# --> 457     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     458 elif engine and engine != io.engine:
#     459     raise ValueError(
#     460         "Engine should not be specified when passing "
#     461         "an ExcelFile - ExcelFile already has the engine set"
#     462     )
#
# File /usr/local/lib/python3.9/dist-packages/pandas/io/excel/_base.py:1419, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1416 self.engine = engine
#    1417 self.storage_options = storage_options
# -> 1419 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File /usr/local/lib/python3.9/dist-packages/pandas/io/excel/_openpyxl.py:524, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options)
#     509 def __init__(
#     510     self,
#     511     filepath_or_buffer: FilePath | ReadBuffer[bytes],
#     512     storage_options: StorageOptions = None,
#     513 ) -> None:
#     514     """
#     515     Reader using openpyxl engine.
#     516
#    (...)
#     522         passed to fsspec for appropriate URLs (see ``_get_filepath_or_buffer``)
#     523     """
# --> 524     import_optional_dependency("openpyxl")
#     525     super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File /usr/local/lib/python3.9/dist-packages/pandas/compat/_optional.py:141, in import_optional_dependency(name, extra, errors, min_version)
#     139 except ImportError:
#     140     if errors == "raise":
# --> 141         raise ImportError(msg)
#     142     else:
#     143         return None
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %% [markdown]
# En el caso de múltiples páginas obtendremos un vector de dataframes. En este ejemplo cargamos datos de accidentes por distritos en la ciudad de Madrid. Se trata de un "libro" excel con hojas de nombre '2009', ..., '2016'
#
# Ojo: para manejar esta posibilidad necesitaremos una versión actualizada de xlrd

# %%
#!pip install --upgrade xlrd

# %%
import pandas as pd
fichero = "https://github.com/RafaelCaballero/tdm/raw/master/datos/madrid/accidentes_madrid_2009_2016.xlsx"
df_acc = pd.read_excel(fichero,sheet_name='2016')
df_acc

# %% [markdown]
# La grabación de ficheros excel se realiza con la función de pandas to_excel, asociada al dataframe. Esta función depende a su vez de dos librerías
#
#
#     - xlwt para grabar ficheros .xls  (formato hasta Excel2003)
#     - openpyxl para ficheros .xlsx (Excel2007 o posterior).

# %%
df_acc.to_excel("./accidentes.xlsx")

# %% [markdown]
# **Ejercicio 5**
# Cargar el fichero situado en https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/ciudades_ejemplo.csv
# como un dataframe Pandas, y grabarlo a continuación en formato excel.

# %%
# solución

# %% [markdown]
# <a name="Carga-de-ficheros-PDF"></a>
# ### Extracción de información de ficheros PDF
#
# Este es un tema complejo porque va a depender mucho del formato del interno del PDF. En los casos más sencillos podremos extraer por ejemplo tablas de datos con el paquete tabula-py

# %%
# !pip install tabula-py
#!pip install tabulate

# %%
from tabula import read_pdf

fichero = "./resumen.pdf"
 
# extraer tablas del fichero
df = read_pdf(fichero,pages="all")[0]  # 0 porque nos quedamos con la primera tabla

df

# %%
df = df.iloc[1:]  # todas las filas a partir de la 1 (es decir, quitar la 0)
df

# %% [markdown]
# Ahora podemos grabar el fichero en formato CSV

# %%
df.to_csv("resumen.csv")

# %% [markdown]
# **Nota** Si queremos cargar el fichero resumen.csv debemos tener en cuenta que los separadores de miles son puntos y los de valores decimales la coma

# %%
fichero = "resumen.csv"
df = pd.read_csv(fichero, thousands='.', decimal=',')
df

# %% [markdown]
# Proximamente veremos como manipular esta información, de momento calculemos por ejemplo la media de la columna Dif

# %%
df.Dif.mean()

# %% [markdown]
# **Ejercicio 6** Grabar el fichero en formato excel, con nombre "resumen.xlsx"

# %%
# solución
